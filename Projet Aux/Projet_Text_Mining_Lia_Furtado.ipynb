# %%
# Owner: Lia Furtado

# %%
import json
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import re
import nltk 
from nltk.stem import PorterStemmer
from nltk import word_tokenize
from nltk.corpus import stopwords
import unicodedata
from collections import Counter
import spacy
import string
import spacy
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics.pairwise import euclidean_distances
import math
from gensim.models import word2vec
import time
from gensim.models.doc2vec import TaggedDocument
from gensim.models import Doc2Vec
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE, MDS, Isomap, LocallyLinearEmbedding
from plotly.subplots import make_subplots
import plotly.express as px
from gensim.models.ldamodel import LdaModel
from nltk.collocations import *
from gensim.corpora.dictionary import Dictionary
import umap

import ipywidgets as widgets


import seaborn as sns
from itertools import combinations
#from sentence_transformers import SentenceTransformer
import nxviz as nv
from nxviz import annotate
import networkx as nx

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# Out:
# C:\Users\lfurtado\Anaconda3\lib\site-packages\nxviz\__init__.py:18: UserWarning:
# nxviz has a new API! Version 0.7.3 onwards, the old class-based API is being
# deprecated in favour of a new API focused on advancing a grammar of network
# graphics. If your plotting code depends on the old API, please consider
# pinning nxviz at version 0.7.3, as the new API will break your old code.
#
# To check out the new API, please head over to the docs at
# https://ericmjl.github.io/nxviz/ to learn more. We hope you enjoy using it!
#
# (This deprecation message will go away in version 1.0.)
#
#   warnings.warn(

# %% [markdown]
# ## Objectif:
# ## Demarche:
# ## Introduction/Plan

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\lfurtado\Documents\Master - DataMining\Projets\TextMining

# %%
data = pd.read_csv('dblp_2016_cleaned.csv')

# %%
import nltk 
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\lfurtado\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
data['text_clean_tokenized'] = data['text_clean'].apply(lambda x:nltk.word_tokenize(x))

# %%
#delete when there is no venue
data = data[~data['venue'].isnull()]

# %%
def cleanup_authors(msg):
    #removing []
    sentence = re.sub(r"[\([{})\]]",r'', msg)
    #removing '' and .
    sentence = sentence.replace("'", "").replace(".", "") 
    sentence = sentence.replace("\\", "").replace("/", "") 
    sentence = sentence.replace('"','') 
    #remove all non latin caracters
    sentence = re.sub(r'[^\x00-\x7f]',r'', sentence)
    #removing digits
    sentence = re.sub("\S*\d+\S*", "", sentence)
    #remove diactric accents and greek letters
    sentence = ''.join(c for c in unicodedata.normalize('NFD', sentence)
                  if unicodedata.category(c) != 'Mn')
    #hyphen the authors
    sentence = list(sentence.split(", "))
    sentence = [word.lower().replace(' ','-') for word in sentence]
    return sentence

# %%
def cleanup_venue(msg):
    #removing pontuation
    No_Punctuation = [char if char not in string.punctuation else ' ' for char in msg ]
    sentence = ''.join(No_Punctuation)
    #removing []
    sentence = re.sub(r"[\([{})\]]",r'', msg)
    #removing '' and .
    sentence = sentence.replace(":", "") 
    sentence = sentence.replace(".", "")
    sentence = sentence.replace("\\", "").replace("/", "") 
    sentence = sentence.replace('"','') 
    sentence = sentence.replace("& ", "")
    sentence = sentence.replace("and ", "")
    #hyphen the authors
    sentence = list(sentence.split(", "))
    sentence = [word.lower().replace(' ','-') for word in sentence]
    return sentence

# %%
data['authors_clean'] = data['authors'].apply(lambda x:cleanup_authors(x))
data['venue_clean'] = data['venue'].apply(lambda x:cleanup_venue(x))

# %%
bag_of_authors = [item for sublist in data['authors_clean'] for item in sublist]

bag_of_venues = [item for sublist in data['venue_clean'] for item in sublist]

# %%
# Top 10 authors
plt.figure(figsize=(8, 10)) 

plt.subplot(2, 1, 1)

top10authors = pd.DataFrame.from_records(
    Counter(bag_of_authors).most_common(10), columns=["Author", "Count"]
)
sns.barplot(x="Count", y="Author", data=top10authors, palette="RdBu_r")
plt.title("Top 10 Authors")

plt.subplot(2, 1, 2)

# TOP 10 Venues
top10venues = pd.DataFrame.from_records(
    Counter(bag_of_venues).most_common(10),
    columns=["Venues", "Count"],
)

sns.barplot(x="Count", y="Venues", data=top10venues)
plt.title("Top 10 Venues")
# Out:
# Text(0.5, 1.0, 'Top 10 Venues')

# %%
#Each author now becomes a node and the connection between two is an edge.

# %%
data[data['venue_clean'].apply(lambda x: len(set(x))>1)]
data[data['authors_clean'].apply(lambda x: '-keskin' in x) ]
# Out:
#                                                 abstract  \
# 11     With the recent development of technology, wir...
# 51     Motif finding is one of the NP-complete proble...
# 66     Electrodynamic bearings exploit repulsive forc...
# 67     In this paper, we propose a collective decisio...
# 200    The goal of regression testing is to ensure th...
# ...                                                  ...
# 10839  The homogeneous weight on a finite Frobenius r...
# 10889  An optimal control method is developed for unk...
# 10959  This paper introduces a new system-level fault...
# 11079  We present a new practical identity-based encr...
# 11147  In this article, we show explicitly all possib...
#
#                                                  authors  n_citation  \
# 11     ['Biljana L. Stojkoska', 'Ilinka Ivanoska', 'D...          50
# 51     ['Jhoirene B. Clemente', 'Francis George C. Ca...          50
# 66     ['Nicola Amati', 'Fabrizio Impinna', 'J.G. Det...           0
# 67     ['Alexander Scheidler', 'Arne Brutschy', 'Elis...           7
# 200    ['Rawad Abou Assi', 'Fadi A. Zaraket', 'Wes Ma...          50
# ...                                                  ...         ...
# 10839                        ['Heide Gluesing-Luerssen']          50
# 10889  ['Ruizhuo Song', 'Frank L. Lewis', 'Qinglai We...          50
# 10959                  ['Mourad Elhadef', 'Amiya Nayak']           1
# 11079                ['Jong Hwan Park', 'Dong Hoon Lee']           3
# 11147  ['Fabio Enrique Brochero Martínez', 'Carmen Ro...           0
#
#                                               references  \
# 11     ['103e12c7-7e82-4a02-a695-155e93f74e14', 'a695...
# 51     ['36653de4-ccd6-49d2-8f6d-25c1b7f4f856', '4e71...
# 66                                                   NaN
# 67     ['0203ea7e-643e-442f-bef1-b2ee7b1da5e3', '074a...
# 200    ['022d57a1-668e-4823-bf3e-e1a761a075de', '0302...
# ...                                                  ...
# 10839  ['0138c35e-2003-44e8-8286-37897684db04', '27dc...
# 10889  ['08298542-c6c8-4956-902a-b3c68716950a', '0fa4...
# 10959  ['0a463b6b-450b-498b-ab7f-ef90e462e1c0', '1879...
# 11079  ['047084da-1175-4614-b4ee-4ef56c1f3999', '06f6...
# 11147  ['1b1853e7-8fe1-404c-9948-73d3b820ce31', 'abf8...
#
#                                                    title  \
# 11     Wireless Sensor Networks Localization Methods:...
# 51        PROJECTION Algorithm for Motif Finding on GPUs
# 66     Test and theory of electrodynamic bearings cou...
# 67     The ${k}$ -Unanimity Rule for Self-Organized D...
# 200    UCov: a User-Defined Coverage Criterion for Te...
# ...                                                  ...
# 10839  The homogeneous weight partition and its chara...
# 10889  Off-Policy Actor-Critic Structure for Optimal ...
# 10959  Using support vector machines to solve the com...
# 11079  An efficient IBE scheme with tight security re...
# 11147  Weight enumerator of some irreducible cyclic c...
#
#                                                    venue  year  \
# 11     arXiv: Distributed, Parallel, and Cluster Comp...  2016
# 51     arXiv: Distributed, Parallel, and Cluster Comp...  2016
# 66     Proceedings of the Institution of Mechanical E...  2016
# 67     IEEE Transactions on Systems, Man, and Cyberne...  2016
# 200         Software Testing, Verification & Reliability  2016
# ...                                                  ...   ...
# 10839                    Designs, Codes and Cryptography  2016
# 10889  IEEE Transactions on Systems, Man, and Cyberne...  2016
# 10959  International Journal of Parallel, Emergent an...  2016
# 11079                    Designs, Codes and Cryptography  2016
# 11147                    Designs, Codes and Cryptography  2016
#
#                                          id  \
# 11     91c9a7ae-4cf8-4e7b-a01a-647db5ba4dec
# 51     c49bdd5a-4ead-456c-924e-abbb1546c65a
# 66     f52dcb18-54f8-45c2-8d62-b096a2bb0b9c
# 67     35858dee-d441-4d3a-be7e-a2abe5d2ca87
# 200    9fd02565-1585-4fb6-bb25-704caa4798a7
# ...                                     ...
# 10839  32e777af-bd22-46c7-bed4-64fe216a48f7
# 10889  358ee0b3-9f08-429d-8629-f14bda918252
# 10959  39228f36-c7eb-4390-93eb-a133cb1a2df0
# 11079  3fd29171-4c26-4b3e-839f-6a6b23ad6e0b
# 11147  442e0381-39af-40e0-aa92-0782324794c1
#
#                                                     text  \
# 11     Wireless Sensor Networks Localization Methods:...
# 51     PROJECTION Algorithm for Motif Finding on GPUs...
# 66     Test and theory of electrodynamic bearings cou...
# 67     The ${k}$ -Unanimity Rule for Self-Organized D...
# 200    UCov: a User-Defined Coverage Criterion for Te...
# ...                                                  ...
# 10839  The homogeneous weight partition and its chara...
# 10889  Off-Policy Actor-Critic Structure for Optimal ...
# 10959  Using support vector machines to solve the com...
# 11079  An efficient IBE scheme with tight security re...
# 11147  Weight enumerator of some irreducible cyclic c...
#
#                                               text_clean  \
# 11     wireless sensor localization multidimensional ...
# 51     projection motif finding gpus motif finding np...
# 66     test theory electrodynamic bearings coupled ac...
# 67     unanimity rule self organized decision making ...
# 200    ucov user defined coverage criterion test case...
# ...                                                  ...
# 10839  homogeneous weight partition character theoret...
# 10889  policy actor critic structure optimal unknown ...
# 10959  support vector machines solve comparison level...
# 11079  efficient ibe scheme tight security reduction ...
# 11147  weight enumerator irreducible cyclic codes art...
#
#                                     text_clean_tokenized  \
# 11     [wireless, sensor, localization, multidimensio...
# 51     [projection, motif, finding, gpus, motif, find...
# 66     [test, theory, electrodynamic, bearings, coupl...
# 67     [unanimity, rule, self, organized, decision, m...
# 200    [ucov, user, defined, coverage, criterion, tes...
# ...                                                  ...
# 10839  [homogeneous, weight, partition, character, th...
# 10889  [policy, actor, critic, structure, optimal, un...
# 10959  [support, vector, machines, solve, comparison,...
# 11079  [efficient, ibe, scheme, tight, security, redu...
# 11147  [weight, enumerator, irreducible, cyclic, code...
#
#                                            authors_clean  \
# 11     [biljana-l-stojkoska, ilinka-ivanoska, danco-d...
# 51     [jhoirene-b-clemente, francis-george-c-cabarle...
# 66     [nicola-amati, fabrizio-impinna, jg-detoni, an...
# 67     [alexander-scheidler, arne-brutschy, eliseo-fe...
# 200         [rawad-abou-assi, fadi-a-zaraket, wes-masri]
# ...                                                  ...
# 10839                          [heide-gluesing-luerssen]
# 10889  [ruizhuo-song, frank-l-lewis, qinglai-wei, hua...
# 10959                      [mourad-elhadef, amiya-nayak]
# 11079                    [jong-hwan-park, dong-hoon-lee]
# 11147  [fabio-enrique-brochero-martnez, carmen-rosa-g...
#
#                                              venue_clean
# 11      [arxiv-distributed, parallel, cluster-computing]
# 51      [arxiv-distributed, parallel, cluster-computing]
# 66     [proceedings-of-the-institution-of-mechanical-...
# 67      [ieee-transactions-on-systems, man, cybernetics]
# 200         [software-testing, verification-reliability]
# ...                                                  ...
# 10839                      [designs, codes-cryptography]
# 10889   [ieee-transactions-on-systems, man, cybernetics]
# 10959  [international-journal-of-parallel, emergent-d...
# 11079                      [designs, codes-cryptography]
# 11147                      [designs, codes-cryptography]
#
# [215 rows x 13 columns]

# %%
data[data['authors_clean'].apply(lambda x: '-keskin' in x) ]
# Out:
#                                                abstract  \
# 8905  With high-order methods becoming increasingly ...
#
#                                                 authors  n_citation  \
# 8905  ['David Moxey', 'D. Ekelschot', 'Ü. Keskin', '...          12
#
#                                              references  \
# 8905  ['10be84e2-41ff-444e-84f5-cdb26b8919c8', '29f5...
#
#                                                   title  \
# 8905  High-order curvilinear meshing using a thermo-...
#
#                       venue  year                                    id  \
# 8905  Computer-aided Design  2016  64e57559-cc34-43b0-99d7-2da15c1d051f
#
#                                                    text  \
# 8905  High-order curvilinear meshing using a thermo-...
#
#                                              text_clean  \
# 8905  curvilinear meshing thermo elastic analogy bec...
#
#                                    text_clean_tokenized  \
# 8905  [curvilinear, meshing, thermo, elastic, analog...
#
#                                           authors_clean  \
# 8905  [david-moxey, d-ekelschot, -keskin, spencer-j-...
#
#                   venue_clean
# 8905  [computer-aided-design]

# %%
data.head()
# Out:
#                                             abstract  \
# 0  In this article, we show how to compute the wi...
# 1  Traditional methods on video summarization are...
# 2  Decision tree is an important method for both ...
# 3  Full-reference image quality assessment (FR-IQ...
# 4  The Fomin-Kirillov algebra E n is a noncommuta...
#
#                                              authors  n_citation  \
# 0              ['Alexandr Andoni', 'Huy L. Nguyêݱn']           0
# 1  ['Linbo Wang', 'Xianyong Fang', 'Yanwen Guo', ...           3
# 2  ['Singh Vijendra', 'Hem Jyotsana Parashar', 'N...           0
# 3            ['Ashirbani Saha', 'Q. M. Jonathan Wu']          50
# 4                                  ['Ricky Ini Liu']           1
#
#                                           references  \
# 0  ['04d59cae-87b1-4706-9f5f-009ee3e94626', '228e...
# 1  ['0f80ec27-572e-473b-a403-f0f7c47c4743', '18a8...
# 2  ['6d903194-6be4-4780-9ccf-d60916e00770', '7396...
# 3  ['02acc8f4-e6d9-4958-bd08-a1185631f22a', '1086...
# 4  ['7ff3b6e7-35b3-4cca-af97-c39d38bdf080', 'd885...
#
#                                                title  \
# 0             Width of Points in the Streaming Model
# 1  Multi-view Metric Learning for Multi-view Vide...
# 2  A New Method for Classification of Datasets fo...
# 3  Full-reference image quality assessment by com...
# 4  On the commutative quotient of Fomin-Kirillov ...
#
#                                venue  year  \
# 0   symposium on discrete algorithms  2016
# 1                        cyberworlds  2016
# 2                    arXiv: Learning  2016
# 3                  Signal Processing  2016
# 4  European Journal of Combinatorics  2016
#
#                                      id  \
# 0  2a68616f-ae27-46aa-8d7b-292a23e3291f
# 1  348045c5-4d43-4c96-b106-e1038e5d4aaa
# 2  82f3e31c-2139-42f9-88ab-2116621eb207
# 3  0db3464c-7e35-4bb1-be09-f6f079258e0f
# 4  221a3099-ae5a-4e38-b793-d27d1795313f
#
#                                                 text  \
# 0  Width of Points in the Streaming Model In this...
# 1  Multi-view Metric Learning for Multi-view Vide...
# 2  A New Method for Classification of Datasets fo...
# 3  Full-reference image quality assessment by com...
# 4  On the commutative quotient of Fomin-Kirillov ...
#
#                                           text_clean  \
# 0  width points streaming article compute width d...
# 1  multi view metric multi view video summarizati...
# 2  classification datasets mining decision tree i...
# 3  full reference quality assessment combining gl...
# 4  commutative quotient fomin kirillov algebras f...
#
#                                 text_clean_tokenized  \
# 0  [width, points, streaming, article, compute, w...
# 1  [multi, view, metric, multi, view, video, summ...
# 2  [classification, datasets, mining, decision, t...
# 3  [full, reference, quality, assessment, combini...
# 4  [commutative, quotient, fomin, kirillov, algeb...
#
#                                        authors_clean  \
# 0                     [alexandr-andoni, huy-l-nguyn]
# 1  [linbo-wang, xianyong-fang, yanwen-guo, yanwei...
# 2  [singh-vijendra, hem-jyotsana-parashar, nisha-...
# 3                  [ashirbani-saha, q-m-jonathan-wu]
# 4                                    [ricky-ini-liu]
#
#                            venue_clean
# 0   [symposium-on-discrete-algorithms]
# 1                        [cyberworlds]
# 2                     [arxiv-learning]
# 3                  [signal-processing]
# 4  [european-journal-of-combinatorics]

# %%
df_connections = data[['title', 'text_clean', 'text_clean_tokenized', 'authors_clean', 'venue_clean']]
df_connections.reset_index(inplace=True, drop=True)

# %%
top20authors = pd.DataFrame.from_records(
    Counter(bag_of_authors).most_common(20), columns=["Name", "Count"])

articles_20_common_authors = []
for index, connection in df_connections.iterrows():
    for author in list(top20authors['Name']):
        if (author in connection['authors_clean']):
            articles_20_common_authors.append(connection)
            
df_20 = pd.DataFrame(articles_20_common_authors)

# %%
df_20
# Out:
#                                                    title  \
# 89                  An Algebra of Reversible Computation
# 100    Advanced interference management technique: po...
# 137    Energy Dissipation Versus Delay Tradeoffs in a...
# 137    Energy Dissipation Versus Delay Tradeoffs in a...
# 216    Formal verification and validation of a moveme...
# ...                                                  ...
# 10884  An interval mean---average absolute deviation ...
# 10894  Evaluating the Use of Spatial Covariance Struc...
# 10970  A genetic algorithm for the multi-objective op...
# 10992  A new semi-smooth Newton multigrid method for ...
# 11085  Subspace-based continuous-time identification ...
#
#                                               text_clean  \
# 89     algebra reversible computation design axiomati...
# 100    advanced interference management technique pot...
# 137    energy dissipation versus delay tradeoffs buff...
# 137    energy dissipation versus delay tradeoffs buff...
# 216    formal verification validation movement actor ...
# ...                                                  ...
# 10884  interval mean average absolute deviation multi...
# 10894  evaluating spatial covariance structures cardi...
# 10970  genetic multi objective optimization mixed ass...
# 10992  semi smooth newton multigrid constrained semi ...
# 11085  subspace continuous identification fractional ...
#
#                                     text_clean_tokenized  \
# 89     [algebra, reversible, computation, design, axi...
# 100    [advanced, interference, management, technique...
# 137    [energy, dissipation, versus, delay, tradeoffs...
# 137    [energy, dissipation, versus, delay, tradeoffs...
# 216    [formal, verification, validation, movement, a...
# ...                                                  ...
# 10884  [interval, mean, average, absolute, deviation,...
# 10894  [evaluating, spatial, covariance, structures, ...
# 10970  [genetic, multi, objective, optimization, mixe...
# 10992  [semi, smooth, newton, multigrid, constrained,...
# 11085  [subspace, continuous, identification, fractio...
#
#                                            authors_clean  \
# 89                                           [yong-wang]
# 100                        [namyoon-lee, robert-w-heath]
# 137    [chen-dong, li-li, bo-zhang, lie-liang-yang, l...
# 137    [chen-dong, li-li, bo-zhang, lie-liang-yang, l...
# 216    [muhammad-ali-imran, nazir-ahmad-zafar, mohamm...
# ...                                                  ...
# 10884                                       [peng-zhang]
# 10894  [samantha-r-seals, charles-r-katholi, jing-zha...
# 10970  [xiaosong-zhao, chia-yu-hsu, pei-chann-chang, ...
# 10992                           [jun-liu, mingqing-xiao]
# 11085  [yangsheng-hu, yuan-fan, yiheng-wei, yong-wang...
#
#                                              venue_clean
# 89                                        [springerplus]
# 100                       [ieee-wireless-communications]
# 137          [ieee-transactions-on-vehicular-technology]
# 137          [ieee-transactions-on-vehicular-technology]
# 216                                  [wireless-networks]
# ...                                                  ...
# 10884                                   [soft-computing]
# 10894  [communications-in-statistics---simulation-com...
# 10970  [engineering-applications-of-artificial-intell...
# 10992                   [journal-of-global-optimization]
# 11085         [international-journal-of-systems-science]
#
# [185 rows x 5 columns]

# %%
df_20['authors_combination'] = df_20['authors_clean'].apply(lambda x: list(combinations(x[::-1], 2)))
df_20 = df_20.explode('authors_combination','venue_clean')

df_20 = df_20[~df_20['authors_combination'].isnull()] 
df_20.reset_index(inplace=True, drop=True)
df_20['From'], df_20['To'] = zip(*df_20.authors_combination)

# %%
df_graph = df_20[['From', 'To', 'title']]

# %%
df_graph
# Out:
#                 From              To  \
# 0     robert-w-heath     namyoon-lee
# 1        lajos-hanzo  lie-liang-yang
# 2        lajos-hanzo        bo-zhang
# 3        lajos-hanzo           li-li
# 4        lajos-hanzo       chen-dong
# ...              ...             ...
# 1434       yong-wang        yuan-fan
# 1435       yong-wang    yangsheng-hu
# 1436      yiheng-wei        yuan-fan
# 1437      yiheng-wei    yangsheng-hu
# 1438        yuan-fan    yangsheng-hu
#
#                                                   title
# 0     Advanced interference management technique: po...
# 1     Energy Dissipation Versus Delay Tradeoffs in a...
# 2     Energy Dissipation Versus Delay Tradeoffs in a...
# 3     Energy Dissipation Versus Delay Tradeoffs in a...
# 4     Energy Dissipation Versus Delay Tradeoffs in a...
# ...                                                 ...
# 1434  Subspace-based continuous-time identification ...
# 1435  Subspace-based continuous-time identification ...
# 1436  Subspace-based continuous-time identification ...
# 1437  Subspace-based continuous-time identification ...
# 1438  Subspace-based continuous-time identification ...
#
# [1439 rows x 3 columns]

# %%
MG= nx.from_pandas_edgelist(df_graph, 'From', 'To', edge_attr=['title'], 
                                 create_using=nx.MultiGraph())

MG.edges(data=True)
# Out:
# MultiEdgeDataView([('robert-w-heath', 'namyoon-lee', {'title': 'Advanced interference management technique: potentials and limitations'}), ('robert-w-heath', 'namyoon-lee', {'title': 'Cooperative Base Station Coloring for Pair-Wise Multi-Cell Coordination'}), ('robert-w-heath', 'namyoon-lee', {'title': 'Spectral Efficiency Scaling Laws in Dense Random Wireless Networks With Multiple Receive Antennas'}), ('robert-w-heath', 'tianyang-bai', {'title': 'Performance Analysis of Outdoor mmWave Ad Hoc Networks'}), ('robert-w-heath', 'tianyang-bai', {'title': 'Analyzing Uplink SINR and Rate in Massive MIMO Systems Using Stochastic Geometry'}), ('robert-w-heath', 'andrew-thornburg', {'title': 'Performance Analysis of Outdoor mmWave Ad Hoc Networks'}), ('robert-w-heath', 'matthew-c-valenti', {'title': 'Device-to-Device Millimeter Wave Communications: Interference, Coverage, Rate, and Finite Topologies'}), ('robert-w-heath', 'kiran-venugopal', {'title': 'Device-to-Device Millimeter Wave Communications: Interference, Coverage, Rate, and Finite Topologies'}), ('robert-w-heath', 'chih-lin-i', {'title': 'Energy-Efficient Hybrid Analog and Digital Precoding for MmWave MIMO Systems With Large Antenna Arrays'}), ('robert-w-heath', 'shuangfeng-han', {'title': 'Energy-Efficient Hybrid Analog and Digital Precoding for MmWave MIMO Systems With Large Antenna Arrays'}), ('robert-w-heath', 'linglong-dai', {'title': 'Energy-Efficient Hybrid Analog and Digital Precoding for MmWave MIMO Systems With Large Antenna Arrays'}), ('robert-w-heath', 'xinyu-gao', {'title': 'Energy-Efficient Hybrid Analog and Digital Precoding for MmWave MIMO Systems With Large Antenna Arrays'}), ('robert-w-heath', 'jeonghun-park', {'title': 'Cooperative Base Station Coloring for Pair-Wise Multi-Cell Coordination'}), ('robert-w-heath', 'jianhua-mo', {'title': 'Near Maximum-Likelihood Detector and Channel Estimator for Uplink Multiuser Massive MIMO Systems With One-Bit ADCs'}), ('robert-w-heath', 'junil-choi', {'title': 'Near Maximum-Likelihood Detector and Channel Estimator for Uplink Multiuser Massive MIMO Systems With One-Bit ADCs'}), ('robert-w-heath', 'franois-baccelli', {'title': 'Spectral Efficiency Scaling Laws in Dense Random Wireless Networks With Multiple Receive Antennas'}), ('namyoon-lee', 'jeonghun-park', {'title': 'Cooperative Base Station Coloring for Pair-Wise Multi-Cell Coordination'}), ('namyoon-lee', 'franois-baccelli', {'title': 'Spectral Efficiency Scaling Laws in Dense Random Wireless Networks With Multiple Receive Antennas'}), ('lajos-hanzo', 'lie-liang-yang', {'title': 'Energy Dissipation Versus Delay Tradeoffs in a Buffer-Aided Two-Hop Link'}), ('lajos-hanzo', 'lie-liang-yang', {'title': 'Energy Dissipation Versus Delay Tradeoffs in a Buffer-Aided Two-Hop Link'}), ('lajos-hanzo', 'bo-zhang', {'title': 'Energy Dissipation Versus Delay Tradeoffs in a Buffer-Aided Two-Hop Link'}), ('lajos-hanzo', 'bo-zhang', {'title': 'Energy Dissipation Versus Delay Tradeoffs in a Buffer-Aided Two-Hop Link'}), ('lajos-hanzo', 'li-li', {'title': 'Energy Dissipation Versus Delay Tradeoffs in a Buffer-Aided Two-Hop Link'}), ('lajos-hanzo', 'li-li', {'title': 'Energy Dissipation Versus Delay Tradeoffs in a Buffer-Aided Two-Hop Link'}), ('lajos-hanzo', 'chen-dong', {'title': 'Energy Dissipation Versus Delay Tradeoffs in a Buffer-Aided Two-Hop Link'}), ('lajos-hanzo', 'chen-dong', {'title': 'Energy Dissipation Versus Delay Tradeoffs in a Buffer-Aided Two-Hop Link'}), ('lajos-hanzo', 'bashir-m-al-hashimi', {'title': 'A Survey of FPGA-Based LDPC Decoders'}), ('lajos-hanzo', 'bashir-m-al-hashimi', {'title': '20 Years of Turbo Coding and Energy-Aware Design Guidelines for Energy-Constrained Wireless Applications'}), ('lajos-hanzo', 'robert-g-maunder', {'title': 'A Survey of FPGA-Based LDPC Decoders'}), ('lajos-hanzo', 'robert-g-maunder', {'title': '20 Years of Turbo Coding and Energy-Aware Design Guidelines for Energy-Constrained Wireless Applications'}), ('lajos-hanzo', 'lei-xu', {'t ...

# %%
from pyvis.network import Network
net = Network(height='650px', width='100%', font_color='black', notebook =True)
net.from_nx(MG)
net.show("example.html")
# Out:
#         <iframe
#             width="100%"
#             height="650px"
#             src="example.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Limit to TOP 50 authors
G = nx.from_pandas_edgelist(
    df_graph, source="From", target="To", edge_attr="title"
)

top50authors = pd.DataFrame.from_records(
    Counter(bag_of_authors).most_common(50), columns=["Name", "Count"]
)

top50_nodes = (n for n in list(G.nodes()) if n in list(top50authors["Name"]))

G_50 = G.subgraph(top50_nodes)

for n in G_50.nodes():
    G_50.nodes[n]["publications"] = int(
        top50authors[top50authors["Name"] == n]["Count"]
    )

ax = nv.circos(G_50, group_by="publications", node_color_by="publications")
annotate.circos_group(G_50, group_by="publications")

# %% [markdown]
# ## Search by Title and find most similiar documents

# %%
def get_cosine_similarity(feature_vec_1, feature_vec_2):    
    return cosine_similarity(feature_vec_1.reshape(1, -1), feature_vec_2.reshape(1, -1))[0][0]

# %%
def text_document_similarity(title, n):
    text = df_connections["text_clean"][df_connections["title"] == title].iloc[0]
    df = df_connections[df_connections["title"] != title]
    df.reset_index(inplace=True)
    
    tagged_docs = []

    for i, list_tokens in enumerate(df['text_clean_tokenized']):
        tagged_docs.append(TaggedDocument(words=list_tokens, tags=[str(i+1)]))

    print('Training Doc2Vec...')

    d2v_model = Doc2Vec(vector_size=100, window=10, min_count=5, workers=11,alpha=0.025)
    d2v_model.build_vocab(tagged_docs)
    d2v_model.train(tagged_docs,total_examples=d2v_model.corpus_count, epochs=20)
    
    
    
    #getting the query and cleaning words that are not in the vocabulary
    query = word_tokenize(text)
    #turning the query into a vector with the same shape as the vectorizer 
    query_vec = d2v_model.infer_vector(query)
    
    print('Comparing text documents...')

    list_similar_values = []
    #Comparing the query with every document in the dataset
    for index, row in df.iterrows():
        document_vec = d2v_model.infer_vector(df['text_clean_tokenized'].iloc[index])
        list_similar_values.append(get_cosine_similarity(document_vec, query_vec))

    #get the top 5 similar documents
    top_ids = np.argsort(list_similar_values)[-n:]
    most_similars_doc = []
    for ids in top_ids:
        most_similars_doc.append({"title" : df['title'].iloc[ids], "cossine_similarity": list_similar_values[ids]})
    return most_similars_doc

# %%
def authors_or_venues_in_common(title, most_similars_doc):
    authors = df_connections["authors_clean"][df_connections["title"] == title].iloc[0]
    venues = df_connections["venue_clean"][df_connections["title"] == title].iloc[0]
    #taking out the query author
    updated_docs = []
    
    print('Checking common authors and venues...')

    for doc in most_similars_doc:
        article = df_connections[df_connections["title"] == doc['title']]
            
        for author in authors:
            if (author in article['authors_clean']):
                doc['author'] = author
            else:
                doc['author'] = 'No authors in common'

        for venue in venues:
            if (venue in article['venue_clean']):
                doc['venue'] = venue
            else:
                doc['venue'] = 'No venues in common'
        
        updated_docs.append(doc)
        
    return updated_docs

# %%
def find_similiar_documents(title, number_of_documents):
    
    most_similars_doc = text_document_similarity(title, number_of_documents)
    updated_docs = authors_or_venues_in_common(title, most_similars_doc)
    
    results =  pd.DataFrame(updated_docs[::-1])
    print("\n")
    print("Similar documents of: "+ str(title) + "\n")
    print(results)

    return results

# %%
dropdown = widgets.Dropdown(options = df_connections.title)

def dropdown_eventhandler(change):
    title = change.new
    results = find_similiar_documents(title, 10)

# %%
dropdown.observe(dropdown_eventhandler, names='value')

print("Choose from the listbox the Title you want to find similar documents: ")
display(dropdown)
# Out:
# Choose from the listbox the Title you want to find similar documents:
# Dropdown(options=('Width of Points in the Streaming Model', 'Multi-view Metric Learning for Multi-view Video S…
# Training Doc2Vec...
# Comparing text documents...
# Checking common authors and venues...
#
#
# Similar documents of: The Rainbow Connection Number of the Power Graph of a Finite Group
#
#                                                title  cossine_similarity  \
# 0             Compatibility of fuzzy power relations            0.479005
# 1  On the power of randomization in network inter...            0.445044
# 2             The cost of getting local monotonicity            0.404433
# 3  Spatial power indices with applications on rea...            0.397078
# 4  The power conjugacy problem in Higman-Thompson...            0.382759
# 5  Power usage of production supercomputers and p...            0.374406
# 6  Thompson’s group $F$ is 1-counter graph automatic            0.370330
# 7  Generalized Fibonacci and Lucas cubes arising ...            0.368048
# 8                  Observing CoAP groups efficiently            0.367709
# 9  Energy landscapes for the self-assembly of sup...            0.360908
#
#                  author                venue
# 0  No authors in common  No venues in common
# 1  No authors in common  No venues in common
# 2  No authors in common  No venues in common
# 3  No authors in common  No venues in common
# 4  No authors in common  No venues in common
# 5  No authors in common  No venues in common
# 6  No authors in common  No venues in common
# 7  No authors in common  No venues in common
# 8  No authors in common  No venues in common
# 9  No authors in common  No venues in common

# %%
def authors_or_venues_in_common(title):
    authors = df_connections["authors_clean"][df_connections["title"] == title][0]
    venues = df_connections["venue_clean"][df_connections["title"] == title][0]
    #taking out the query author
    df = df_connections[df_connections["title"] != title]

    list_common_authors = []
    list_common_venues = []
    for index, article in df.iterrows():
        
        print('Checking common authors...')
            
        for author in authors:
            if (author in article['authors_clean']):
                list_common_authors.append({"title" : article['title'], "author": author})
                
        print('Checking common venues...')

        for venue in venues:
            if (venue in article['venue_clean']):
                list_common_venues.append({"title" : article['title'], "author": venue})
                
    return list_common_authors, list_common_venues

# %%
#model for semantic search (query similarity)
model = SentenceTransformer('multi-qa-MiniLM-L6-cos-v1')
embeddings = model.encode(data['text_clean'].values)
print(embeddings)
# Out:
# [[ 0.02990917  0.02470112  0.00049384 ...  0.14277485 -0.04096054
#   -0.00470103]
#  [ 0.03741887 -0.08630216 -0.02435325 ... -0.02804396 -0.05163825
#    0.01938225]
#  [-0.02655261  0.0862579   0.04219936 ...  0.01161415 -0.01834993
#    0.01689634]
#  ...
#  [-0.01083803 -0.0375764  -0.07169445 ... -0.08485531  0.00271295
#    0.05114171]
#  [-0.00584158  0.04895869  0.01795788 ... -0.02700021  0.06420294
#    0.03360017]
#  [ 0.05884707  0.0363559  -0.00641246 ... -0.0240707   0.00848056
#   -0.00777332]]

# %%
embeddings.shape
# Out:
# (11130, 384)
